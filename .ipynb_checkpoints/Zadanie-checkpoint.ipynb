# %%
import csv, string, math
from collections import Counter

filename = 'data.csv'

rows = []
prog_lang_loc = ['javascript,10001','swift,10475','python,10750','java,11462','c++,12090','ruby,12631','rust,13303','c,13624','scala,14288','r,14819','go,15192','mathematica,15859','kotlin,16489','fortran,17106','julia,17565','php,18026','matlab,18380','haskell,18711','perl,19360']
langs = ['javascript','swift','python','java','c++','ruby','rust','c','scala','r','go','mathematica','kotlin','fortran','julia','php','matlab','haskell','perl']
index_list = []

with open(filename, 'r', encoding="utf8") as csvfile:
    
    csvreader = csv.reader(csvfile)
    
    for row in csvreader:
        rows.append(row)

# %%
cleared_rows = [x.replace(';', '') for row in rows for x in row] #usunięcie znaków
cleared_rows = list(map(lambda s: s.strip(), cleared_rows)) #usunięcie znaków nowego wiersza 
cleared_rows = list(filter(None, cleared_rows)) #usunięcie pustych elementów
cleared_rows = list(map(lambda s: s.lower(), cleared_rows)) #małe litery

# %%
for lang in prog_lang_loc:
    for row in cleared_rows:
        if lang in row:
            index_list.append(cleared_rows.index(row))
            break

# %%
train_dict = {} # słownik treningowy
#test_dict = {} # słownik testowy

"""for lang in langs:
        if langs.index(lang) < len(langs) - 1: 
        train_dict[lang] = cleared_rows[index_list[langs.index(lang)]:int(round(index_list[langs.index(lang) + 1]*0.8))]
        test_dict[lang] = cleared_rows[int(round(index_list[langs.index(lang) + 1]*0.8)):index_list[langs.index(lang) + 1]]
    else:
        train_dict[lang] = cleared_rows[index_list[langs.index(lang)]:int(round(len(cleared_rows)*0.8))]
        test_dict[lang] = cleared_rows[int(round(len(cleared_rows)*0.8)):]"""

for lang in langs:
    if langs.index(lang) < len(langs) - 1: 
        train_dict[lang] = cleared_rows[index_list[langs.index(lang)]:index_list[langs.index(lang) + 1]]
    else:
        train_dict[lang] = cleared_rows[index_list[langs.index(lang)]:]

# %%
def clear_dict(dirty_dict,langs):
    
    cleared_dict = {}
    
    for lang in langs:
        dirty_dict[lang] = [''.join(x for x in par if x not in string.punctuation) for par in dirty_dict[lang]]
        dirty_dict[lang] = [element for element in lang_dict[lang] if not element.isdigit()]
        new = []
        for element in lang_dict[lang]:
            for x in (element.split()):
                new.append(x)

        cleared_dict[lang] = new
    
    return(cleared_dict)

# %%
"""all_words = Counter()

for lang in langs:
    for word in lang_dict_clear[lang]:
        all_words[word] += 1
        #word.isalpha() - sprawdzenie czy element składa się tylko z liter
        #len(word) == 1 - elementy jednoznakowe """
# Out:
# 'all_words = Counter()\n\nfor lang in langs:\n    for word in lang_dict_clear[lang]:\n        all_words[word] += 1\n        #word.isalpha() - sprawdzenie czy element składa się tylko z liter\n        #len(word) == 1 - elementy jednoznakowe '

# %%
def calc_prob(lang, code, trained_data, all_words ):
    
    prob = 0
    for word in code:
        try:
            if prob == 0:
                prob = trained_data[lang][word]/all_words[word]
            else:
                prob = prob * trained_data[lang][word]/all_words[word]
            print(prob)
        except(KeyError):
            continue
            
    return(prob)

# %%
def language(trained_data, all_words, code, langs):
    
    lang_chance = {}
    
    for lang in langs:
        prob = calc_prob(lang, code, trained_data, all_words )
        lang_chance[lang] = prob
    
    print(lang_chance)
        
    return(max(lang_chance, key=lang_chance.get))

# %%
def read_file(filename):
    file_object = open(filename, 'r')
    words = file_object.read().split()
    #print(words)
    return(words)

# %%
#Train the model

train_dict = clear_dict(train_dict,langs) #clearing train dict 

trained_data = {} #słownik zawierający ilości występujących słów w danym języku
all_words = Counter() #słownik zawierający ilości ogólnie występujących słów

for lang in langs:
    trained_data[lang] = {}
    for word in train_dict[lang]:
        if word in trained_data[lang]:
            trained_data[lang][word] +=1
        else:
            trained_data[lang][word] = 1 
        all_words[word] += 1

# %%
filename = 'test_data.txt'#enter here te file name (code.txt)
code = read_file(filename)

language(trained_data, all_words, code, langs)
# Out:
# 0.0009541984732824427
# 5.992550798392152e-05
# 1.4796421724425066e-06
# 4.920425276530901e-08
# 1.636245935188423e-09
# 8.181229675942115e-11
# 8.972961580065546e-12
# 6.917681883596891e-14
# 7.587134969106267e-15
# 1.785208228025004e-15
# 8.92604114012502e-17
# 0.0009541984732824427
# 8.451033177219702e-06
# 5.2166871464319144e-08
# 3.4695306437076866e-09
# 2.3075263188554684e-10
# 6.085989479635036e-13
# 0.4076812977099237
# 0.03643528506103182
# 0.0010495761128692294
# 6.766863299801614e-06
# 4.362755435908743e-08
# 6.8168053686074104e-09
# 3.5183511579909214e-10
# 5.853211502439755e-12
# 3.021012388356003e-13
# 5.923553702658829e-15
# 9.25555266040442e-16
# 0.0016698473282442748
# 0.00011831446448107583
# 2.6778994018350496e-06
# 1.6083752769759207e-07
# 9.660075467415608e-09
# 1.5093867917836887e-09
# 2.9213937905490744e-11
# 2.6078581210014057e-13
# 5.047467330970463e-15
# 9.896994766608751e-17
# 1.5464054322826172e-17
# 0.00047709923664122136
# 2.074344507135745e-05
# 8.109577291271431e-07
# 5.2559527065926136e-08
# 3.4064708753280937e-09
# 1.0645221485400293e-10
# 5.150913621967884e-12
# 3.5530749269001435e-14
# 1.7192298033387792e-15
# 1.348415532030415e-16
# 4.213798537595047e-18
# 0.2588263358778626
# 0.009169370997283377
# 7.546807405171504e-05
# 1.8950245944441508e-06
# 4.758460128566921e-08
# 2.9740375803543255e-09
# 2.8781008842138633e-11
# 4.0873820631968033e-13
# 3.955531028900132e-15
# 2.4722068930625824e-16
# 0.00047709923664122136
# 8.451033177219702e-06
# 2.069285901417993e-06
# 9.830336823838444e-09
# 4.669993740540828e-11
# 1.2051596749782783e-12
# 1.0024659499717876e-14
# 2.5870089031530004e-16
# 0.0019083969465648854
# 0.00017977652395176455
# 8.138031948433788e-06
# 8.367233391161988e-07
# 8.602890117143136e-08
# 5.37680632321446e-09
# 5.376806323214461e-10
# 8.617725695555739e-12
# 8.617725695555739e-13
# 5.386078559722337e-14
# 0.3160782442748092
# 0.02188625523964057
# 0.010087492126912526
# 0.002847910909260679
# 0.0008040250683762759
# 5.0251566773517246e-06
# 2.5936292528266965e-07
# 9.30844014658232e-08
# 4.804356204687649e-09
# 9.420306283701272e-11
# 5.887691427313295e-13
# 0.043478260869565216
